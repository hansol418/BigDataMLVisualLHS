# %% [markdown]
# # 영문 분석 -> 워드 클라우드로 그리기(시각화)
#
# ## 샘플 데이터 영문 학술 문서의 제목만 추출, 그 단어의 빈도 분석 시각화
# ## 데이터 수집 : Big data 키워드로 검색 후, 해당 학술 연구 정보 서비스에서 수집 해보기.
# ## 조합, pandas.concat(), 정제 re 정규식, 기본적인 유효성 체크.
# ## 변환 : word_tokenize(), lower(),
# ## matplotlib.pyplot 이용하기.
# ## 단어 빈도 구해주는 Counter() 이용.
#
# ## 비정형 빅데이터 분석을 말하고 -> 자연어 처리 (nature language processing )
# ## 자연어 처리 예) 음성, 텍스트 정보 추출.
#
# ## 단어 빈도를 추출해서, 해당 단어 시각화하기.

# %% [markdown]
# # 관련 단어 용어 정리
# ## 텍스트 분석: 자연어 처리와 데이터 마이닝 결합하여 발전되었고,
# ## 비정형 텍스트 데이터에서 정보를 추출하는 분석 방법.
# ## 분석 방법 : 1) 텍스트 분류 2) 텍스트 군집화 3) 감성 분석.
#
# ## 전처리 : 분석 작업의 정확도를 높이기 위해서 사용할 데이터 정리하고 변환하는 작업.
# ### 수행하는 작업
# ### 정제 (cleaning): 불필요한 기호, 문자 필터하는 작업, 정규식을 이용해서 작업을 함.
# ### 정규화 ( normallization) : 형태가 다른 단어를 특정의 형태로 변환 작업 , 대문자, 소문자 통합 하는 작업, 의미가 비슷한 단어끼리 통합작업.
# ### 토큰화 (tokenization) : 토큰으로 정하는 기본 단위로 분리 작업. 문장 기준, 단어 기준이 될수 도 있다.
# ### 불용어제거(stopword) : 의미 있는 단어를 추출하기 위해서, 조사, 관사, 접미사, 접두사 등. 제거하는 작업.
# ### 어간 추출(semming) : 단수, 복수, 진행형(시제), 분리하는 작업
# ### 표제어 추출(lemmatization ): 단어의 기본형 형태로 일반화 하는 작업.
# ### 예)
# ### Gone -> go
# ### am -> be
# ### going -> go
#
# ## 워드클라우드 : 텍스트 분석에서 빈도를 시각화 할 때 많이 사용됨.

# %% [markdown]
# # 데이터 수집
# # 한국교육학술정보원 (KERIS)의 RISS 사이트
# # https://www.riss.kr/index.do
# # Big data 검색해보기.
# # 한 페이지당 100개씩 내보내기 엑셀 파일 간략 정보 , 반복 10번
# # 1000개의 데이터에서 제목만 추출 및 분류 작업하기.

# %% [markdown]
# # 데이터 준비 작업.
# # 제목 컬럼 빈도 분석 해보기.

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\it\appdata\roaming\python\python312\site-packages (from wordcloud) (2.0.1)
# Requirement already satisfied: pillow in c:\users\it\appdata\roaming\python\python312\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\it\appdata\roaming\python\python312\site-packages (from wordcloud) (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\appdata\roaming\python\python312\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\it\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting click (from nltk)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.7.24-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\it\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 10.0 MB/s eta 0:00:00
# Downloading regex-2024.7.24-cp312-cp312-win_amd64.whl (269 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.4.2 nltk-3.8.1 regex-2024.7.24 tqdm-4.66.5
#   WARNING: The script tqdm.exe is installed in 'C:\Users\it\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'C:\Users\it\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import nltk
# nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# 관련 패키지들 임포트 하기. 
import pandas as pd 
# 경로 이름 지정해서 파일 처리할 때 사용하는 도구
import glob 
# 정규 표현식에 사용하는 도구 
import re 
# 2차원 리스트를 -> 1차원 리스트로 차원 축소시 사용하는 도구 
from functools import reduce
# 자연어 처리 패키지 중에서, 단어 토큰화 작업.
from nltk.tokenize import word_tokenize
# 불용어 처리 작업. 
from nltk.corpus import stopwords 
# 표제어 추출 
from nltk.stem import WordNetLemmatizer 
# 단어의 빈도를 추출하는 도구. 
from collections import Counter 
import matplotlib.pyplot as plt
# 단어의 빈도수를 시각화하는 도구, 빈도가 높을수록 글자 크기가 커짐. 
from wordcloud import STOPWORDS, WordCloud

# %%
# 데이터 조합(병합)하기. 
# 현재 폴더 내부에 있는 , 받았던 엑셀 파일명 10개를 선택하기. 
all_files = glob.glob("./myCabinetExcelData*.xls")
all_files

# 엑셀 파일 읽어서 -> 데이터 프레임 (표형태) 변환 ->특정 리스트에 담아두기 
# 임시로 저장할 리스트 변수 
all_files_data = []

# all_files 에 담겨진 엑셀 파일의 위치가 들어있고, 
# 해당 위치의 엑셀 파일을 읽어서, 데이터 프레임 표 형태로 변환하기. 
# 임시 리스트에 담기. 
for file in all_files:
  # 해당 엑셀 파일의 위치의 물리 파일 읽기
  data_frame = pd.read_excel(file)
  # 임시 리스트에 담기. 
  all_files_data.append(data_frame)

# 샘플 확인 해보기., 첫번째 요소 확인 해보기. 
# all_files_data = [엑셀1,엑셀2,엑셀3,...엑셀10]
all_files_data[0]

# 오류 발생, 모듈 미설치 : xlrd
# cmd -> pip install xlrd
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1                               Big Data on Robotics
# 1          NaN    2  Big Data Applications in Guangzhou Restaurants...
# 2          NaN    3  Toward Business Process Innovation in the Big ...
# 3          NaN    4  National Surveys of Population Health: Big Dat...
# 4          NaN    5  On the Unstructured Big Data Analytical Method...
# ..         ...  ...                                                ...
# 95         NaN   96  Towards a real-time big data analytics platfor...
# 96         NaN   97  An Extended Spatio-Temporal Granger Causality ...
# 97         NaN   98    2017 Index IEEE Transactions on Big Data Vol. 3
# 98         NaN   99  Corporate governance fraud detection from annu...
# 99         NaN  100  Online Similarity Learning for Big Data with O...
#
#                                                    저자               출판사   출판일
# 0                                             unknown  Mary Ann Leibert  2016
# 1        Chang, Victor; Ji, Ziyang; Xu, Qianwen Ariel  Mary Ann Leibert  2021
# 2                    Saide, Saide; Sheng, Margaret L.  Mary Ann Leibert  2020
# 3                                             unknown  Mary Ann Leibert  2015
# 4                     Tarka, Piotr; Jędrych, Elżbieta  Mary Ann Leibert  2020
# ..                                                ...               ...   ...
# 95  Chrimes, Dillon; Kuo, Mu-Hsing; Moa, Belaid; H...      Inderscience  2017
# 96                     Zhu, J. Y.; Sun, C.; Li, V. O.           unknown  2017
# 97                                            unknown           unknown  2018
# 98  Sadasivam, G. Sudha; Subrahmanyam, Mutyala; Hi...      Inderscience  2016
# 99  Cong, Y.; Liu, J.; Fan, B.; Zeng, P.; Yu, H.; ...           unknown  2018
#
# [100 rows x 6 columns]

# %%
# 엑셀 파일 10개를 병합해서 출력해보기. 
# axis=0 , 세로 방향으로 , 밑으로 데이터를 붙이는 작업. 
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)
print(f"all_files_data_concat.shape : {all_files_data_concat.shape}")

# 병합된 파일을 csv 파일로 변환하기. 
all_files_data_concat.to_csv("./riss_Bigdata.csv", encoding="utf-8", index=False)
# Out:
# all_files_data_concat.shape : (1000, 6)

# %%
# 전처리 작업 하기. 
# 데이터 프레임에서 제목 열만 추출 
all_title = all_files_data_concat["제목"]
all_title

#불용어 제거 
# set(), 기본적으로 중복 제거 
stopWords = set(stopwords.words("english"))

# lemma 작업 -> 표제어 추출, 영어, 시제를 제거하고, 원형(사전식 단어 추출)
lemma = WordNetLemmatizer()

# %%
# 임시로 담을 변수, 
words = []

# 기본적인 , 단어 추출(전처리 작업.)
for title in all_title:
  # 영문자, 대 소문자를 제외한 나머지 문자는 모두 공백으로 처리하겠다. 
  print(f"과정1 title 원본: {title}")
  enWords = re.sub(r"[^a-zA-Z]+"," ",str(title))
  print(f"과정2 title enWords(re: 대소문자남기기): {enWords}")
  # 남은 영문자를 -> 모두 소문자 변환하고 -> 각단어를 토큰으로 각각 분리 작업. 
  enWordsToken = word_tokenize(enWords.lower())
  print(f"과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): {enWordsToken}")
  # 컴프리헨션 파이썬 스타일 코드로 , 리스로 변경하기. 
  
  # 불용어 제거 작업, 조사, 관사 등 제거하는 작업. -> 오타:stopwords -> stopWords
  enWordsTokenStop= [w for w in enWordsToken if w not in stopWords]
  print(f"과정4 title enWordsTokenStop(불용어 제거): {enWordsTokenStop}")

  # 표제어 추출 작업. 
  enWordsTokenStopLemma = [lemma.lemmatize(w) for w in enWordsTokenStop]
  print(f"과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): {enWordsTokenStopLemma}")

  words.append(enWordsTokenStopLemma)
  
print(f"words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : {words}")
# Out:
# 과정1 title 원본: Big Data on Robotics
# 과정2 title enWords(re: 대소문자남기기): Big Data on Robotics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'on', 'robotics']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'robotics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'robotics']
# 과정1 title 원본: Big Data Applications in Guangzhou Restaurants Analysis
# 과정2 title enWords(re: 대소문자남기기): Big Data Applications in Guangzhou Restaurants Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'applications', 'in', 'guangzhou', 'restaurants', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'applications', 'guangzhou', 'restaurants', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis']
# 과정1 title 원본: Toward Business Process Innovation in the Big Data Era: A Mediating Role of Big Data Knowledge Management
# 과정2 title enWords(re: 대소문자남기기): Toward Business Process Innovation in the Big Data Era A Mediating Role of Big Data Knowledge Management
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['toward', 'business', 'process', 'innovation', 'in', 'the', 'big', 'data', 'era', 'a', 'mediating', 'role', 'of', 'big', 'data', 'knowledge', 'management']
# 과정4 title enWordsTokenStop(불용어 제거): ['toward', 'business', 'process', 'innovation', 'big', 'data', 'era', 'mediating', 'role', 'big', 'data', 'knowledge', 'management']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['toward', 'business', 'process', 'innovation', 'big', 'data', 'era', 'mediating', 'role', 'big', 'data', 'knowledge', 'management']
# 과정1 title 원본: National Surveys of Population Health: Big Data Analytics for Mobile Health Monitors
# 과정2 title enWords(re: 대소문자남기기): National Surveys of Population Health Big Data Analytics for Mobile Health Monitors
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['national', 'surveys', 'of', 'population', 'health', 'big', 'data', 'analytics', 'for', 'mobile', 'health', 'monitors']
# 과정4 title enWordsTokenStop(불용어 제거): ['national', 'surveys', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitors']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor']
# 과정1 title 원본: On the Unstructured Big Data Analytical Methods in Firms: Conceptual Model, Measurement, and Perception
# 과정2 title enWords(re: 대소문자남기기): On the Unstructured Big Data Analytical Methods in Firms Conceptual Model Measurement and Perception
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['on', 'the', 'unstructured', 'big', 'data', 'analytical', 'methods', 'in', 'firms', 'conceptual', 'model', 'measurement', 'and', 'perception']
# 과정4 title enWordsTokenStop(불용어 제거): ['unstructured', 'big', 'data', 'analytical', 'methods', 'firms', 'conceptual', 'model', 'measurement', 'perception']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['unstructured', 'big', 'data', 'analytical', 'method', 'firm', 'conceptual', 'model', 'measurement', 'perception']
# 과정1 title 원본: Big Data in Business: A Bibliometric Analysis of Relevant Literature
# 과정2 title enWords(re: 대소문자남기기): Big Data in Business A Bibliometric Analysis of Relevant Literature
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'in', 'business', 'a', 'bibliometric', 'analysis', 'of', 'relevant', 'literature']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'business', 'bibliometric', 'analysis', 'relevant', 'literature']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'business', 'bibliometric', 'analysis', 'relevant', 'literature']
# 과정1 title 원본: Call for Special Issue Papers: Big Data in Business
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data in Business
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'in', 'business']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'business']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'business']
# 과정1 title 원본: Big Data for the Social Good: The Drought Early-Warning Experience Report
# 과정2 title enWords(re: 대소문자남기기): Big Data for the Social Good The Drought Early Warning Experience Report
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'for', 'the', 'social', 'good', 'the', 'drought', 'early', 'warning', 'experience', 'report']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'social', 'good', 'drought', 'early', 'warning', 'experience', 'report']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'social', 'good', 'drought', 'early', 'warning', 'experience', 'report']
# 과정1 title 원본: Overcoming Resistance to Big Data and Operational Changes Through Interactive Data Visualization
# 과정2 title enWords(re: 대소문자남기기): Overcoming Resistance to Big Data and Operational Changes Through Interactive Data Visualization
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['overcoming', 'resistance', 'to', 'big', 'data', 'and', 'operational', 'changes', 'through', 'interactive', 'data', 'visualization']
# 과정4 title enWordsTokenStop(불용어 제거): ['overcoming', 'resistance', 'big', 'data', 'operational', 'changes', 'interactive', 'data', 'visualization']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization']
# 과정1 title 원본: Towards quantifying psychiatric diagnosis using machine learning algorithms and big fMRI data
# 과정2 title enWords(re: 대소문자남기기): Towards quantifying psychiatric diagnosis using machine learning algorithms and big fMRI data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['towards', 'quantifying', 'psychiatric', 'diagnosis', 'using', 'machine', 'learning', 'algorithms', 'and', 'big', 'fmri', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['towards', 'quantifying', 'psychiatric', 'diagnosis', 'using', 'machine', 'learning', 'algorithms', 'big', 'fmri', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['towards', 'quantifying', 'psychiatric', 'diagnosis', 'using', 'machine', 'learning', 'algorithm', 'big', 'fmri', 'data']
# 과정1 title 원본: Exploiting Reused-Based Sharing Work Opportunities in Big Data Multiquery Optimization with Flink
# 과정2 title enWords(re: 대소문자남기기): Exploiting Reused Based Sharing Work Opportunities in Big Data Multiquery Optimization with Flink
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunities', 'in', 'big', 'data', 'multiquery', 'optimization', 'with', 'flink']
# 과정4 title enWordsTokenStop(불용어 제거): ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunities', 'big', 'data', 'multiquery', 'optimization', 'flink']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink']
# 과정1 title 원본: Call for Special Issue Papers: Big Scientific Data and Machine Learning in Science and Engineering
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Scientific Data and Machine Learning in Science and Engineering
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'scientific', 'data', 'and', 'machine', 'learning', 'in', 'science', 'and', 'engineering']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering']
# 과정1 title 원본: Big data analysis of swimming pools' impact on household electric intensity in San Antonio, Texas
# 과정2 title enWords(re: 대소문자남기기): Big data analysis of swimming pools impact on household electric intensity in San Antonio Texas
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analysis', 'of', 'swimming', 'pools', 'impact', 'on', 'household', 'electric', 'intensity', 'in', 'san', 'antonio', 'texas']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'swimming', 'pools', 'impact', 'household', 'electric', 'intensity', 'san', 'antonio', 'texas']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'swimming', 'pool', 'impact', 'household', 'electric', 'intensity', 'san', 'antonio', 'texas']
# 과정1 title 원본: Agricultural Disaster Risk Management and Capability Assessment Using Big Data Analytics
# 과정2 title enWords(re: 대소문자남기기): Agricultural Disaster Risk Management and Capability Assessment Using Big Data Analytics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['agricultural', 'disaster', 'risk', 'management', 'and', 'capability', 'assessment', 'using', 'big', 'data', 'analytics']
# 과정4 title enWordsTokenStop(불용어 제거): ['agricultural', 'disaster', 'risk', 'management', 'capability', 'assessment', 'using', 'big', 'data', 'analytics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['agricultural', 'disaster', 'risk', 'management', 'capability', 'assessment', 'using', 'big', 'data', 'analytics']
# 과정1 title 원본: Call for Special Issue Papers: Big Data Analytics for Agricultural Disaster Management
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Analytics for Agricultural Disaster Management
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'for', 'agricultural', 'disaster', 'management']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management']
# 과정1 title 원본: Vehicle Intelligent Classification Based on Big Multimodal Data Analysis and Sparrow Search Optimization
# 과정2 title enWords(re: 대소문자남기기): Vehicle Intelligent Classification Based on Big Multimodal Data Analysis and Sparrow Search Optimization
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['vehicle', 'intelligent', 'classification', 'based', 'on', 'big', 'multimodal', 'data', 'analysis', 'and', 'sparrow', 'search', 'optimization']
# 과정4 title enWordsTokenStop(불용어 제거): ['vehicle', 'intelligent', 'classification', 'based', 'big', 'multimodal', 'data', 'analysis', 'sparrow', 'search', 'optimization']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['vehicle', 'intelligent', 'classification', 'based', 'big', 'multimodal', 'data', 'analysis', 'sparrow', 'search', 'optimization']
# 과정1 title 원본: Big data in support of the Sustainable Development Goals: a celebration of the establishment of the International Research Center of Big Data for Sustainable Development Goals (CBAS)
# 과정2 title enWords(re: 대소문자남기기): Big data in support of the Sustainable Development Goals a celebration of the establishment of the International Research Center of Big Data for Sustainable Development Goals CBAS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'in', 'support', 'of', 'the', 'sustainable', 'development', 'goals', 'a', 'celebration', 'of', 'the', 'establishment', 'of', 'the', 'international', 'research', 'center', 'of', 'big', 'data', 'for', 'sustainable', 'development', 'goals', 'cbas']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'support', 'sustainable', 'development', 'goals', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goals', 'cbas']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas']
# 과정1 title 원본: Big Multimodal Data Analysis: Applications
# 과정2 title enWords(re: 대소문자남기기): Big Multimodal Data Analysis Applications
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'multimodal', 'data', 'analysis', 'applications']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'multimodal', 'data', 'analysis', 'applications']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'multimodal', 'data', 'analysis', 'application']
# 과정1 title 원본: Big data in support of the sustainable development goals (continued): a celebration of the establishment of the International Research Center of Big Data for Sustainable Development Goals (CBAS)
# 과정2 title enWords(re: 대소문자남기기): Big data in support of the sustainable development goals continued a celebration of the establishment of the International Research Center of Big Data for Sustainable Development Goals CBAS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'in', 'support', 'of', 'the', 'sustainable', 'development', 'goals', 'continued', 'a', 'celebration', 'of', 'the', 'establishment', 'of', 'the', 'international', 'research', 'center', 'of', 'big', 'data', 'for', 'sustainable', 'development', 'goals', 'cbas']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'support', 'sustainable', 'development', 'goals', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goals', 'cbas']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas']
# 과정1 title 원본: The Uses of Big Data in Cities
# 과정2 title enWords(re: 대소문자남기기): The Uses of Big Data in Cities
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'uses', 'of', 'big', 'data', 'in', 'cities']
# 과정4 title enWordsTokenStop(불용어 제거): ['uses', 'big', 'data', 'cities']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['us', 'big', 'data', 'city']
# 과정1 title 원본: STGI：a spatio-temporal grid index model for marine big data
# 과정2 title enWords(re: 대소문자남기기): STGI a spatio temporal grid index model for marine big data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['stgi', 'a', 'spatio', 'temporal', 'grid', 'index', 'model', 'for', 'marine', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['stgi', 'spatio', 'temporal', 'grid', 'index', 'model', 'marine', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['stgi', 'spatio', 'temporal', 'grid', 'index', 'model', 'marine', 'big', 'data']
# 과정1 title 원본: A new big data approach based on geoecological information-modeling system
# 과정2 title enWords(re: 대소문자남기기): A new big data approach based on geoecological information modeling system
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'new', 'big', 'data', 'approach', 'based', 'on', 'geoecological', 'information', 'modeling', 'system']
# 과정4 title enWordsTokenStop(불용어 제거): ['new', 'big', 'data', 'approach', 'based', 'geoecological', 'information', 'modeling', 'system']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['new', 'big', 'data', 'approach', 'based', 'geoecological', 'information', 'modeling', 'system']
# 과정1 title 원본: Big Data Literature Search
# 과정2 title enWords(re: 대소문자남기기): Big Data Literature Search
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'literature', 'search']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'literature', 'search']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'literature', 'search']
# 과정1 title 원본: Big data (lost) in the cloud
# 과정2 title enWords(re: 대소문자남기기): Big data lost in the cloud
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'lost', 'in', 'the', 'cloud']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'lost', 'cloud']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'lost', 'cloud']
# 과정1 title 원본: Interview with Dr. Silvio Carta, Author of the Book Big Data, Code and the Discrete City (Routledge 2019)
# 과정2 title enWords(re: 대소문자남기기): Interview with Dr Silvio Carta Author of the Book Big Data Code and the Discrete City Routledge
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['interview', 'with', 'dr', 'silvio', 'carta', 'author', 'of', 'the', 'book', 'big', 'data', 'code', 'and', 'the', 'discrete', 'city', 'routledge']
# 과정4 title enWordsTokenStop(불용어 제거): ['interview', 'dr', 'silvio', 'carta', 'author', 'book', 'big', 'data', 'code', 'discrete', 'city', 'routledge']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['interview', 'dr', 'silvio', 'carta', 'author', 'book', 'big', 'data', 'code', 'discrete', 'city', 'routledge']
# 과정1 title 원본: Online Analytical Processing for Business Intelligence in Big Data
# 과정2 title enWords(re: 대소문자남기기): Online Analytical Processing for Business Intelligence in Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['online', 'analytical', 'processing', 'for', 'business', 'intelligence', 'in', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data']
# 과정1 title 원본: Call for Special Issue Papers: Big Data in Business
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data in Business
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'in', 'business']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'business']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'business']
# 과정1 title 원본: A GIS-based analytical framework for evaluating the effect of COVID-19 on the restaurant industry with big data
# 과정2 title enWords(re: 대소문자남기기): A GIS based analytical framework for evaluating the effect of COVID on the restaurant industry with big data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'gis', 'based', 'analytical', 'framework', 'for', 'evaluating', 'the', 'effect', 'of', 'covid', 'on', 'the', 'restaurant', 'industry', 'with', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['gis', 'based', 'analytical', 'framework', 'evaluating', 'effect', 'covid', 'restaurant', 'industry', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['gi', 'based', 'analytical', 'framework', 'evaluating', 'effect', 'covid', 'restaurant', 'industry', 'big', 'data']
# 과정1 title 원본: The challenges of a Big Data Earth
# 과정2 title enWords(re: 대소문자남기기): The challenges of a Big Data Earth
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'challenges', 'of', 'a', 'big', 'data', 'earth']
# 과정4 title enWordsTokenStop(불용어 제거): ['challenges', 'big', 'data', 'earth']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['challenge', 'big', 'data', 'earth']
# 과정1 title 원본: Call for Special Issue Papers: Big Data Analytics and Intelligent Systems for Cybersecurity
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Analytics and Intelligent Systems for Cybersecurity
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'and', 'intelligent', 'systems', 'for', 'cybersecurity']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'intelligent', 'systems', 'cybersecurity']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity']
# 과정1 title 원본: Call for Special Issue Papers: Big Data and the Internet-of-Things in Complex Information Systems: Selections from IoTBDS 2022 and COMPLEXIS 2022
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data and the Internet of Things in Complex Information Systems Selections from IoTBDS and COMPLEXIS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'and', 'the', 'internet', 'of', 'things', 'in', 'complex', 'information', 'systems', 'selections', 'from', 'iotbds', 'and', 'complexis']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'internet', 'things', 'complex', 'information', 'systems', 'selections', 'iotbds', 'complexis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'internet', 'thing', 'complex', 'information', 'system', 'selection', 'iotbds', 'complexis']
# 과정1 title 원본: Data science for oceanography: from small data to big data
# 과정2 title enWords(re: 대소문자남기기): Data science for oceanography from small data to big data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'science', 'for', 'oceanography', 'from', 'small', 'data', 'to', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'science', 'oceanography', 'small', 'data', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'science', 'oceanography', 'small', 'data', 'big', 'data']
# 과정1 title 원본: Strength in Numbers: Using Big Data to Simplify Sentiment Classification
# 과정2 title enWords(re: 대소문자남기기): Strength in Numbers Using Big Data to Simplify Sentiment Classification
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['strength', 'in', 'numbers', 'using', 'big', 'data', 'to', 'simplify', 'sentiment', 'classification']
# 과정4 title enWordsTokenStop(불용어 제거): ['strength', 'numbers', 'using', 'big', 'data', 'simplify', 'sentiment', 'classification']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['strength', 'number', 'using', 'big', 'data', 'simplify', 'sentiment', 'classification']
# 과정1 title 원본: Optimizing Sentinel-2 image selection in a Big Data context
# 과정2 title enWords(re: 대소문자남기기): Optimizing Sentinel image selection in a Big Data context
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['optimizing', 'sentinel', 'image', 'selection', 'in', 'a', 'big', 'data', 'context']
# 과정4 title enWordsTokenStop(불용어 제거): ['optimizing', 'sentinel', 'image', 'selection', 'big', 'data', 'context']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['optimizing', 'sentinel', 'image', 'selection', 'big', 'data', 'context']
# 과정1 title 원본: Atmospheric and ecosystem big data providing key contributions in reaching United Nations' Sustainable Development Goals
# 과정2 title enWords(re: 대소문자남기기): Atmospheric and ecosystem big data providing key contributions in reaching United Nations Sustainable Development Goals
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['atmospheric', 'and', 'ecosystem', 'big', 'data', 'providing', 'key', 'contributions', 'in', 'reaching', 'united', 'nations', 'sustainable', 'development', 'goals']
# 과정4 title enWordsTokenStop(불용어 제거): ['atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contributions', 'reaching', 'united', 'nations', 'sustainable', 'development', 'goals']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal']
# 과정1 title 원본: A Message from the Editor-in-Chief of Big Data
# 과정2 title enWords(re: 대소문자남기기): A Message from the Editor in Chief of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'message', 'from', 'the', 'editor', 'in', 'chief', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['message', 'editor', 'chief', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['message', 'editor', 'chief', 'big', 'data']
# 과정1 title 원본: Internet of Things-Based Optimized Routing and Big Data Gathering System for Landslide Detection
# 과정2 title enWords(re: 대소문자남기기): Internet of Things Based Optimized Routing and Big Data Gathering System for Landslide Detection
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['internet', 'of', 'things', 'based', 'optimized', 'routing', 'and', 'big', 'data', 'gathering', 'system', 'for', 'landslide', 'detection']
# 과정4 title enWordsTokenStop(불용어 제거): ['internet', 'things', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection']
# 과정1 title 원본: Research Dilemmas with Behavioral Big Data
# 과정2 title enWords(re: 대소문자남기기): Research Dilemmas with Behavioral Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['research', 'dilemmas', 'with', 'behavioral', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['research', 'dilemmas', 'behavioral', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['research', 'dilemma', 'behavioral', 'big', 'data']
# 과정1 title 원본: A comparison on scalability for batch big data processing on Apache Spark and Apache Flink
# 과정2 title enWords(re: 대소문자남기기): A comparison on scalability for batch big data processing on Apache Spark and Apache Flink
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'comparison', 'on', 'scalability', 'for', 'batch', 'big', 'data', 'processing', 'on', 'apache', 'spark', 'and', 'apache', 'flink']
# 과정4 title enWordsTokenStop(불용어 제거): ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink']
# 과정1 title 원본: Call for Papers: Special Issue on Computational Propaganda and Political Big Data
# 과정2 title enWords(re: 대소문자남기기): Call for Papers Special Issue on Computational Propaganda and Political Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'papers', 'special', 'issue', 'on', 'computational', 'propaganda', 'and', 'political', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'papers', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data']
# 과정1 title 원본: Call for Special Issue Papers: Multimedia Big Data Analytics for Engineering Education
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Multimedia Big Data Analytics for Engineering Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'for', 'engineering', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정1 title 원본: Call for Special Issue Papers: Multimedia Big Data Analytics for Engineering Education
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Multimedia Big Data Analytics for Engineering Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'for', 'engineering', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education']
# 과정1 title 원본: Big Data Assurance: An Approach Based on Service-Level Agreements
# 과정2 title enWords(re: 대소문자남기기): Big Data Assurance An Approach Based on Service Level Agreements
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'assurance', 'an', 'approach', 'based', 'on', 'service', 'level', 'agreements']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'assurance', 'approach', 'based', 'service', 'level', 'agreements']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'assurance', 'approach', 'based', 'service', 'level', 'agreement']
# 과정1 title 원본: Prediction and Big Data Impact Analysis of Telecom Churn by Backpropagation Neural Network Algorithm from the Perspective of Business Model
# 과정2 title enWords(re: 대소문자남기기): Prediction and Big Data Impact Analysis of Telecom Churn by Backpropagation Neural Network Algorithm from the Perspective of Business Model
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['prediction', 'and', 'big', 'data', 'impact', 'analysis', 'of', 'telecom', 'churn', 'by', 'backpropagation', 'neural', 'network', 'algorithm', 'from', 'the', 'perspective', 'of', 'business', 'model']
# 과정4 title enWordsTokenStop(불용어 제거): ['prediction', 'big', 'data', 'impact', 'analysis', 'telecom', 'churn', 'backpropagation', 'neural', 'network', 'algorithm', 'perspective', 'business', 'model']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['prediction', 'big', 'data', 'impact', 'analysis', 'telecom', 'churn', 'backpropagation', 'neural', 'network', 'algorithm', 'perspective', 'business', 'model']
# 과정1 title 원본: Deep Learning on Big, Sparse, Behavioral Data
# 과정2 title enWords(re: 대소문자남기기): Deep Learning on Big Sparse Behavioral Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['deep', 'learning', 'on', 'big', 'sparse', 'behavioral', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['deep', 'learning', 'big', 'sparse', 'behavioral', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['deep', 'learning', 'big', 'sparse', 'behavioral', 'data']
# 과정1 title 원본: Earth observation and geospatial big data management and engagement of stakeholders in Hungary to support the SDGs
# 과정2 title enWords(re: 대소문자남기기): Earth observation and geospatial big data management and engagement of stakeholders in Hungary to support the SDGs
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['earth', 'observation', 'and', 'geospatial', 'big', 'data', 'management', 'and', 'engagement', 'of', 'stakeholders', 'in', 'hungary', 'to', 'support', 'the', 'sdgs']
# 과정4 title enWordsTokenStop(불용어 제거): ['earth', 'observation', 'geospatial', 'big', 'data', 'management', 'engagement', 'stakeholders', 'hungary', 'support', 'sdgs']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['earth', 'observation', 'geospatial', 'big', 'data', 'management', 'engagement', 'stakeholder', 'hungary', 'support', 'sdgs']
# 과정1 title 원본: Combining Human Computing and Machine Learning to Make Sense of Big (Aerial) Data for Disaster Response
# 과정2 title enWords(re: 대소문자남기기): Combining Human Computing and Machine Learning to Make Sense of Big Aerial Data for Disaster Response
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['combining', 'human', 'computing', 'and', 'machine', 'learning', 'to', 'make', 'sense', 'of', 'big', 'aerial', 'data', 'for', 'disaster', 'response']
# 과정4 title enWordsTokenStop(불용어 제거): ['combining', 'human', 'computing', 'machine', 'learning', 'make', 'sense', 'big', 'aerial', 'data', 'disaster', 'response']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['combining', 'human', 'computing', 'machine', 'learning', 'make', 'sense', 'big', 'aerial', 'data', 'disaster', 'response']
# 과정1 title 원본: Data behaviours model for Big Data visual analytics
# 과정2 title enWords(re: 대소문자남기기): Data behaviours model for Big Data visual analytics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'behaviours', 'model', 'for', 'big', 'data', 'visual', 'analytics']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'behaviours', 'model', 'big', 'data', 'visual', 'analytics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'behaviour', 'model', 'big', 'data', 'visual', 'analytics']
# 과정1 title 원본: RST-DE: Rough Sets-Based New Differential Evolution Algorithm for Scalable Big Data Feature Selection in Distributed Computing Platforms
# 과정2 title enWords(re: 대소문자남기기): RST DE Rough Sets Based New Differential Evolution Algorithm for Scalable Big Data Feature Selection in Distributed Computing Platforms
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['rst', 'de', 'rough', 'sets', 'based', 'new', 'differential', 'evolution', 'algorithm', 'for', 'scalable', 'big', 'data', 'feature', 'selection', 'in', 'distributed', 'computing', 'platforms']
# 과정4 title enWordsTokenStop(불용어 제거): ['rst', 'de', 'rough', 'sets', 'based', 'new', 'differential', 'evolution', 'algorithm', 'scalable', 'big', 'data', 'feature', 'selection', 'distributed', 'computing', 'platforms']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['rst', 'de', 'rough', 'set', 'based', 'new', 'differential', 'evolution', 'algorithm', 'scalable', 'big', 'data', 'feature', 'selection', 'distributed', 'computing', 'platform']
# 과정1 title 원본: Big Data, Efficient Markets, and the End of Daily Fantasy Sports As We Know It?
# 과정2 title enWords(re: 대소문자남기기): Big Data Efficient Markets and the End of Daily Fantasy Sports As We Know It
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'efficient', 'markets', 'and', 'the', 'end', 'of', 'daily', 'fantasy', 'sports', 'as', 'we', 'know', 'it']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'efficient', 'markets', 'end', 'daily', 'fantasy', 'sports', 'know']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'efficient', 'market', 'end', 'daily', 'fantasy', 'sport', 'know']
# 과정1 title 원본: Furthest-Pair-Based Binary Search Tree for Speeding Big Data Classification Using K-Nearest Neighbors
# 과정2 title enWords(re: 대소문자남기기): Furthest Pair Based Binary Search Tree for Speeding Big Data Classification Using K Nearest Neighbors
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['furthest', 'pair', 'based', 'binary', 'search', 'tree', 'for', 'speeding', 'big', 'data', 'classification', 'using', 'k', 'nearest', 'neighbors']
# 과정4 title enWordsTokenStop(불용어 제거): ['furthest', 'pair', 'based', 'binary', 'search', 'tree', 'speeding', 'big', 'data', 'classification', 'using', 'k', 'nearest', 'neighbors']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['furthest', 'pair', 'based', 'binary', 'search', 'tree', 'speeding', 'big', 'data', 'classification', 'using', 'k', 'nearest', 'neighbor']
# 과정1 title 원본: Remotely sensed big data for the oceans and polar regions
# 과정2 title enWords(re: 대소문자남기기): Remotely sensed big data for the oceans and polar regions
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['remotely', 'sensed', 'big', 'data', 'for', 'the', 'oceans', 'and', 'polar', 'regions']
# 과정4 title enWordsTokenStop(불용어 제거): ['remotely', 'sensed', 'big', 'data', 'oceans', 'polar', 'regions']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region']
# 과정1 title 원본: Call for Papers: Special Issue on Big Data in Robotics
# 과정2 title enWords(re: 대소문자남기기): Call for Papers Special Issue on Big Data in Robotics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'papers', 'special', 'issue', 'on', 'big', 'data', 'in', 'robotics']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'papers', 'special', 'issue', 'big', 'data', 'robotics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'paper', 'special', 'issue', 'big', 'data', 'robotics']
# 과정1 title 원본: Spatial patterns of urban green space and its actual utilization status in China based on big data analysis
# 과정2 title enWords(re: 대소문자남기기): Spatial patterns of urban green space and its actual utilization status in China based on big data analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['spatial', 'patterns', 'of', 'urban', 'green', 'space', 'and', 'its', 'actual', 'utilization', 'status', 'in', 'china', 'based', 'on', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['spatial', 'patterns', 'urban', 'green', 'space', 'actual', 'utilization', 'status', 'china', 'based', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['spatial', 'pattern', 'urban', 'green', 'space', 'actual', 'utilization', 'status', 'china', 'based', 'big', 'data', 'analysis']
# 과정1 title 원본: Big Data, Little Data, and Care Coordination for Medicare Beneficiaries with Medigap Coverage
# 과정2 title enWords(re: 대소문자남기기): Big Data Little Data and Care Coordination for Medicare Beneficiaries with Medigap Coverage
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'little', 'data', 'and', 'care', 'coordination', 'for', 'medicare', 'beneficiaries', 'with', 'medigap', 'coverage']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiaries', 'medigap', 'coverage']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage']
# 과정1 title 원본: Big data analytics capability for digital transformation in the insurance sector
# 과정2 title enWords(re: 대소문자남기기): Big data analytics capability for digital transformation in the insurance sector
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analytics', 'capability', 'for', 'digital', 'transformation', 'in', 'the', 'insurance', 'sector']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'capability', 'digital', 'transformation', 'insurance', 'sector']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'capability', 'digital', 'transformation', 'insurance', 'sector']
# 과정1 title 원본: SOOM: Sort-Based Optimizer for Big Data Multi-Query
# 과정2 title enWords(re: 대소문자남기기): SOOM Sort Based Optimizer for Big Data Multi Query
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['soom', 'sort', 'based', 'optimizer', 'for', 'big', 'data', 'multi', 'query']
# 과정4 title enWordsTokenStop(불용어 제거): ['soom', 'sort', 'based', 'optimizer', 'big', 'data', 'multi', 'query']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['soom', 'sort', 'based', 'optimizer', 'big', 'data', 'multi', 'query']
# 과정1 title 원본: Call for Special Issue Papers: Big Scientific Data and Machine Learning in Science and Engineering
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Scientific Data and Machine Learning in Science and Engineering
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'scientific', 'data', 'and', 'machine', 'learning', 'in', 'science', 'and', 'engineering']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering']
# 과정1 title 원본: Call for Special Issue Papers: Big Data Analytics for Agricultural Disaster Management
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Analytics for Agricultural Disaster Management
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'for', 'agricultural', 'disaster', 'management']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management']
# 과정1 title 원본: Optimal Feature Selection for Big Data Classification: Firefly with Lion-Assisted Model
# 과정2 title enWords(re: 대소문자남기기): Optimal Feature Selection for Big Data Classification Firefly with Lion Assisted Model
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['optimal', 'feature', 'selection', 'for', 'big', 'data', 'classification', 'firefly', 'with', 'lion', 'assisted', 'model']
# 과정4 title enWordsTokenStop(불용어 제거): ['optimal', 'feature', 'selection', 'big', 'data', 'classification', 'firefly', 'lion', 'assisted', 'model']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['optimal', 'feature', 'selection', 'big', 'data', 'classification', 'firefly', 'lion', 'assisted', 'model']
# 과정1 title 원본: Health big data analytics: current perspectives, challenges and potential solutions
# 과정2 title enWords(re: 대소문자남기기): Health big data analytics current perspectives challenges and potential solutions
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['health', 'big', 'data', 'analytics', 'current', 'perspectives', 'challenges', 'and', 'potential', 'solutions']
# 과정4 title enWordsTokenStop(불용어 제거): ['health', 'big', 'data', 'analytics', 'current', 'perspectives', 'challenges', 'potential', 'solutions']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution']
# 과정1 title 원본: Agile Big Data Analytics for Web-Based Systems: An Architecture-Centric Approach
# 과정2 title enWords(re: 대소문자남기기): Agile Big Data Analytics for Web Based Systems An Architecture Centric Approach
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['agile', 'big', 'data', 'analytics', 'for', 'web', 'based', 'systems', 'an', 'architecture', 'centric', 'approach']
# 과정4 title enWordsTokenStop(불용어 제거): ['agile', 'big', 'data', 'analytics', 'web', 'based', 'systems', 'architecture', 'centric', 'approach']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach']
# 과정1 title 원본: A Big Data Application for Energy Consumption Management of Commercial Buildings
# 과정2 title enWords(re: 대소문자남기기): A Big Data Application for Energy Consumption Management of Commercial Buildings
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'application', 'for', 'energy', 'consumption', 'management', 'of', 'commercial', 'buildings']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'application', 'energy', 'consumption', 'management', 'commercial', 'buildings']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'application', 'energy', 'consumption', 'management', 'commercial', 'building']
# 과정1 title 원본: Intelligent big data analysis: a review
# 과정2 title enWords(re: 대소문자남기기): Intelligent big data analysis a review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['intelligent', 'big', 'data', 'analysis', 'a', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['intelligent', 'big', 'data', 'analysis', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['intelligent', 'big', 'data', 'analysis', 'review']
# 과정1 title 원본: Analyzing Big Smart Metering Data Towards Differentiated User Services: A Sublinear Approach
# 과정2 title enWords(re: 대소문자남기기): Analyzing Big Smart Metering Data Towards Differentiated User Services A Sublinear Approach
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'services', 'a', 'sublinear', 'approach']
# 과정4 title enWordsTokenStop(불용어 제거): ['analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'services', 'sublinear', 'approach']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['analyzing', 'big', 'smart', 'metering', 'data', 'towards', 'differentiated', 'user', 'service', 'sublinear', 'approach']
# 과정1 title 원본: Health big data analytics: current perspectives, challenges and potential solutions
# 과정2 title enWords(re: 대소문자남기기): Health big data analytics current perspectives challenges and potential solutions
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['health', 'big', 'data', 'analytics', 'current', 'perspectives', 'challenges', 'and', 'potential', 'solutions']
# 과정4 title enWordsTokenStop(불용어 제거): ['health', 'big', 'data', 'analytics', 'current', 'perspectives', 'challenges', 'potential', 'solutions']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['health', 'big', 'data', 'analytics', 'current', 'perspective', 'challenge', 'potential', 'solution']
# 과정1 title 원본: Clustering Big Spatiotemporal-Interval Data
# 과정2 title enWords(re: 대소문자남기기): Clustering Big Spatiotemporal Interval Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['clustering', 'big', 'spatiotemporal', 'interval', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['clustering', 'big', 'spatiotemporal', 'interval', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['clustering', 'big', 'spatiotemporal', 'interval', 'data']
# 과정1 title 원본: A big data analytics framework for border crossing transportation
# 과정2 title enWords(re: 대소문자남기기): A big data analytics framework for border crossing transportation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'analytics', 'framework', 'for', 'border', 'crossing', 'transportation']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation']
# 과정1 title 원본: Improved big data stock index prediction using deep learning with CNN and GRU
# 과정2 title enWords(re: 대소문자남기기): Improved big data stock index prediction using deep learning with CNN and GRU
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'with', 'cnn', 'and', 'gru']
# 과정4 title enWordsTokenStop(불용어 제거): ['improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'cnn', 'gru']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['improved', 'big', 'data', 'stock', 'index', 'prediction', 'using', 'deep', 'learning', 'cnn', 'gru']
# 과정1 title 원본: Scalable big data modelling
# 과정2 title enWords(re: 대소문자남기기): Scalable big data modelling
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['scalable', 'big', 'data', 'modelling']
# 과정4 title enWordsTokenStop(불용어 제거): ['scalable', 'big', 'data', 'modelling']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['scalable', 'big', 'data', 'modelling']
# 과정1 title 원본: Intelligent big data analysis: a review
# 과정2 title enWords(re: 대소문자남기기): Intelligent big data analysis a review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['intelligent', 'big', 'data', 'analysis', 'a', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['intelligent', 'big', 'data', 'analysis', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['intelligent', 'big', 'data', 'analysis', 'review']
# 과정1 title 원본: Leveraging Big Data analytics - case of Kenyan telecoms
# 과정2 title enWords(re: 대소문자남기기): Leveraging Big Data analytics case of Kenyan telecoms
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['leveraging', 'big', 'data', 'analytics', 'case', 'of', 'kenyan', 'telecoms']
# 과정4 title enWordsTokenStop(불용어 제거): ['leveraging', 'big', 'data', 'analytics', 'case', 'kenyan', 'telecoms']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['leveraging', 'big', 'data', 'analytics', 'case', 'kenyan', 'telecom']
# 과정1 title 원본: Guest Editorial: Big Data Analytics and the Web
# 과정2 title enWords(re: 대소문자남기기): Guest Editorial Big Data Analytics and the Web
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['guest', 'editorial', 'big', 'data', 'analytics', 'and', 'the', 'web']
# 과정4 title enWordsTokenStop(불용어 제거): ['guest', 'editorial', 'big', 'data', 'analytics', 'web']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['guest', 'editorial', 'big', 'data', 'analytics', 'web']
# 과정1 title 원본: Guest Editorial: Big Data Analytics and the Web
# 과정2 title enWords(re: 대소문자남기기): Guest Editorial Big Data Analytics and the Web
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['guest', 'editorial', 'big', 'data', 'analytics', 'and', 'the', 'web']
# 과정4 title enWordsTokenStop(불용어 제거): ['guest', 'editorial', 'big', 'data', 'analytics', 'web']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['guest', 'editorial', 'big', 'data', 'analytics', 'web']
# 과정1 title 원본: Investigating class rarity in big data
# 과정2 title enWords(re: 대소문자남기기): Investigating class rarity in big data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['investigating', 'class', 'rarity', 'in', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['investigating', 'class', 'rarity', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['investigating', 'class', 'rarity', 'big', 'data']
# 과정1 title 원본: Guest Editorial: Big Data Infrastructure I
# 과정2 title enWords(re: 대소문자남기기): Guest Editorial Big Data Infrastructure I
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['guest', 'editorial', 'big', 'data', 'infrastructure', 'i']
# 과정4 title enWordsTokenStop(불용어 제거): ['guest', 'editorial', 'big', 'data', 'infrastructure']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['guest', 'editorial', 'big', 'data', 'infrastructure']
# ...
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'u', 's', 'army', 'person', 'event', 'data', 'environment', 'a', 'military', 'civilian', 'big', 'data', 'enterprise']
# 과정4 title enWordsTokenStop(불용어 제거): ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise']
# 과정1 title 원본: Labor Economists Get Their Microscope: Big Data and Labor Market Analysis
# 과정2 title enWords(re: 대소문자남기기): Labor Economists Get Their Microscope Big Data and Labor Market Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['labor', 'economists', 'get', 'their', 'microscope', 'big', 'data', 'and', 'labor', 'market', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['labor', 'economists', 'get', 'microscope', 'big', 'data', 'labor', 'market', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['labor', 'economist', 'get', 'microscope', 'big', 'data', 'labor', 'market', 'analysis']
# 과정1 title 원본: Why Big Data = Big Deal
# 과정2 title enWords(re: 대소문자남기기): Why Big Data Big Deal
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['why', 'big', 'data', 'big', 'deal']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'big', 'deal']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'big', 'deal']
# 과정1 title 원본: Call for Special Issue Papers: Big Data Analytics and Intelligent Systems for Cybersecurity
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Big Data Analytics and Intelligent Systems for Cybersecurity
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'and', 'intelligent', 'systems', 'for', 'cybersecurity']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'big', 'data', 'analytics', 'intelligent', 'systems', 'cybersecurity']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity']
# 과정1 title 원본: Correction to: Big Data 2016;4:60–66
# 과정2 title enWords(re: 대소문자남기기): Correction to Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['correction', 'to', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['correction', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['correction', 'big', 'data']
# 과정1 title 원본: Big Data As an Enabler of Primary Education
# 과정2 title enWords(re: 대소문자남기기): Big Data As an Enabler of Primary Education
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'as', 'an', 'enabler', 'of', 'primary', 'education']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'enabler', 'primary', 'education']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'enabler', 'primary', 'education']
# 과정1 title 원본: Unsupervised Tensor Mining for Big Data Practitioners
# 과정2 title enWords(re: 대소문자남기기): Unsupervised Tensor Mining for Big Data Practitioners
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['unsupervised', 'tensor', 'mining', 'for', 'big', 'data', 'practitioners']
# 과정4 title enWordsTokenStop(불용어 제거): ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioners']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner']
# 과정1 title 원본: Call for Special Issue Papers: Programming Models and Algorithms for Big Data
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Programming Models and Algorithms for Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'programming', 'models', 'and', 'algorithms', 'for', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'programming', 'models', 'algorithms', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'programming', 'model', 'algorithm', 'big', 'data']
# 과정1 title 원본: Big Multimodal Data Analysis: Models and Performance Analysis
# 과정2 title enWords(re: 대소문자남기기): Big Multimodal Data Analysis Models and Performance Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'multimodal', 'data', 'analysis', 'models', 'and', 'performance', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'multimodal', 'data', 'analysis', 'models', 'performance', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis']
# 과정1 title 원본: Using Big Data to Understand the Human Condition: The Kavli Human Project
# 과정2 title enWords(re: 대소문자남기기): Using Big Data to Understand the Human Condition The Kavli Human Project
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['using', 'big', 'data', 'to', 'understand', 'the', 'human', 'condition', 'the', 'kavli', 'human', 'project']
# 과정4 title enWordsTokenStop(불용어 제거): ['using', 'big', 'data', 'understand', 'human', 'condition', 'kavli', 'human', 'project']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['using', 'big', 'data', 'understand', 'human', 'condition', 'kavli', 'human', 'project']
# 과정1 title 원본: SecDedoop: Secure Deduplication with Access Control of Big Data in the HDFS/Hadoop Environment
# 과정2 title enWords(re: 대소문자남기기): SecDedoop Secure Deduplication with Access Control of Big Data in the HDFS Hadoop Environment
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['secdedoop', 'secure', 'deduplication', 'with', 'access', 'control', 'of', 'big', 'data', 'in', 'the', 'hdfs', 'hadoop', 'environment']
# 과정4 title enWordsTokenStop(불용어 제거): ['secdedoop', 'secure', 'deduplication', 'access', 'control', 'big', 'data', 'hdfs', 'hadoop', 'environment']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['secdedoop', 'secure', 'deduplication', 'access', 'control', 'big', 'data', 'hdfs', 'hadoop', 'environment']
# 과정1 title 원본: Toward a General Framework for Multimodal Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): Toward a General Framework for Multimodal Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['toward', 'a', 'general', 'framework', 'for', 'multimodal', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['toward', 'general', 'framework', 'multimodal', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['toward', 'general', 'framework', 'multimodal', 'big', 'data', 'analysis']
# 과정1 title 원본: Big data and analytics: a data management perspective in public administration
# 과정2 title enWords(re: 대소문자남기기): Big data and analytics a data management perspective in public administration
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'analytics', 'a', 'data', 'management', 'perspective', 'in', 'public', 'administration']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration']
# 과정1 title 원본: Big Data in Healthcare: Opportunities and Challenges
# 과정2 title enWords(re: 대소문자남기기): Big Data in Healthcare Opportunities and Challenges
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'in', 'healthcare', 'opportunities', 'and', 'challenges']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'healthcare', 'opportunities', 'challenges']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'healthcare', 'opportunity', 'challenge']
# 과정1 title 원본: A Big Data Guide to Understanding Climate Change: The Case for Theory-Guided Data Science
# 과정2 title enWords(re: 대소문자남기기): A Big Data Guide to Understanding Climate Change The Case for Theory Guided Data Science
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'guide', 'to', 'understanding', 'climate', 'change', 'the', 'case', 'for', 'theory', 'guided', 'data', 'science']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'guide', 'understanding', 'climate', 'change', 'case', 'theory', 'guided', 'data', 'science']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'guide', 'understanding', 'climate', 'change', 'case', 'theory', 'guided', 'data', 'science']
# 과정1 title 원본: Call for Special Issue Papers: Programming Models and Algorithms for Big Data
# 과정2 title enWords(re: 대소문자남기기): Call for Special Issue Papers Programming Models and Algorithms for Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['call', 'for', 'special', 'issue', 'papers', 'programming', 'models', 'and', 'algorithms', 'for', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['call', 'special', 'issue', 'papers', 'programming', 'models', 'algorithms', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['call', 'special', 'issue', 'paper', 'programming', 'model', 'algorithm', 'big', 'data']
# 과정1 title 원본: Common Big Data Challenges and How to Overcome Them
# 과정2 title enWords(re: 대소문자남기기): Common Big Data Challenges and How to Overcome Them
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['common', 'big', 'data', 'challenges', 'and', 'how', 'to', 'overcome', 'them']
# 과정4 title enWordsTokenStop(불용어 제거): ['common', 'big', 'data', 'challenges', 'overcome']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['common', 'big', 'data', 'challenge', 'overcome']
# 과정1 title 원본: Big Data, 3D Printing Technology, and Industry of the Future
# 과정2 title enWords(re: 대소문자남기기): Big Data D Printing Technology and Industry of the Future
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'd', 'printing', 'technology', 'and', 'industry', 'of', 'the', 'future']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'printing', 'technology', 'industry', 'future']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'printing', 'technology', 'industry', 'future']
# 과정1 title 원본: Recent advance in earth observation big data for hydrology
# 과정2 title enWords(re: 대소문자남기기): Recent advance in earth observation big data for hydrology
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['recent', 'advance', 'in', 'earth', 'observation', 'big', 'data', 'for', 'hydrology']
# 과정4 title enWordsTokenStop(불용어 제거): ['recent', 'advance', 'earth', 'observation', 'big', 'data', 'hydrology']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['recent', 'advance', 'earth', 'observation', 'big', 'data', 'hydrology']
# 과정1 title 원본: Big Data and Predictive Analytics in Health Care
# 과정2 title enWords(re: 대소문자남기기): Big Data and Predictive Analytics in Health Care
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'predictive', 'analytics', 'in', 'health', 'care']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'predictive', 'analytics', 'health', 'care']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'predictive', 'analytics', 'health', 'care']
# 과정1 title 원본: Big data drives the development of Earth science
# 과정2 title enWords(re: 대소문자남기기): Big data drives the development of Earth science
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'drives', 'the', 'development', 'of', 'earth', 'science']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'drives', 'development', 'earth', 'science']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'drive', 'development', 'earth', 'science']
# 과정1 title 원본: XDataExplorer: A Three-Stage Comprehensive Self-Tuning Tool for Big Data Platforms
# 과정2 title enWords(re: 대소문자남기기): XDataExplorer A Three Stage Comprehensive Self Tuning Tool for Big Data Platforms
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['xdataexplorer', 'a', 'three', 'stage', 'comprehensive', 'self', 'tuning', 'tool', 'for', 'big', 'data', 'platforms']
# 과정4 title enWordsTokenStop(불용어 제거): ['xdataexplorer', 'three', 'stage', 'comprehensive', 'self', 'tuning', 'tool', 'big', 'data', 'platforms']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['xdataexplorer', 'three', 'stage', 'comprehensive', 'self', 'tuning', 'tool', 'big', 'data', 'platform']
# words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : [['big', 'data', 'robotics'], ['big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis'], ['toward', 'business', 'process', 'innovation', 'big', 'data', 'era', 'mediating', 'role', 'big', 'data', 'knowledge', 'management'], ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor'], ['unstructured', 'big', 'data', 'analytical', 'method', 'firm', 'conceptual', 'model', 'measurement', 'perception'], ['big', 'data', 'business', 'bibliometric', 'analysis', 'relevant', 'literature'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'business'], ['big', 'data', 'social', 'good', 'drought', 'early', 'warning', 'experience', 'report'], ['overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization'], ['towards', 'quantifying', 'psychiatric', 'diagnosis', 'using', 'machine', 'learning', 'algorithm', 'big', 'fmri', 'data'], ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink'], ['call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering'], ['big', 'data', 'analysis', 'swimming', 'pool', 'impact', 'household', 'electric', 'intensity', 'san', 'antonio', 'texas'], ['agricultural', 'disaster', 'risk', 'management', 'capability', 'assessment', 'using', 'big', 'data', 'analytics'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management'], ['vehicle', 'intelligent', 'classification', 'based', 'big', 'multimodal', 'data', 'analysis', 'sparrow', 'search', 'optimization'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['big', 'multimodal', 'data', 'analysis', 'application'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['us', 'big', 'data', 'city'], ['stgi', 'spatio', 'temporal', 'grid', 'index', 'model', 'marine', 'big', 'data'], ['new', 'big', 'data', 'approach', 'based', 'geoecological', 'information', 'modeling', 'system'], ['big', 'data', 'literature', 'search'], ['big', 'data', 'lost', 'cloud'], ['interview', 'dr', 'silvio', 'carta', 'author', 'book', 'big', 'data', 'code', 'discrete', 'city', 'routledge'], ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'business'], ['gi', 'based', 'analytical', 'framework', 'evaluating', 'effect', 'covid', 'restaurant', 'industry', 'big', 'data'], ['challenge', 'big', 'data', 'earth'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'internet', 'thing', 'complex', 'information', 'system', 'selection', 'iotbds', 'complexis'], ['data', 'science', 'oceanography', 'small', 'data', 'big', 'data'], ['strength', 'number', 'using', 'big', 'data', 'simplify', 'sentiment', 'classification'], ['optimizing', 'sentinel', 'image', 'selection', 'big', 'data', 'context'], ['atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal'], ['message', 'editor', 'chief', 'big', 'data'], ['internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection'], ['research', 'dilemma', 'behavioral', 'big', 'data'], ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink'], ['call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'multimedia', ...

# %%
# 2차원 리스트 -> 1차원 리스트 , 차원 축소 
# reduce 함수 이용하기. 차원 축소 
# list 함수 이용해서, 1차원 리스트로 만들기.
# print(f"words : {words}")
result = reduce(lambda x,y : x+y, words)
words2 = list(result)
#result
print(f"result 타입 조사 : {type(words2)}")
print(f"words2 : {words2}")
# Out:
# result 타입 조사 : <class 'list'>
# words2 : ['big', 'data', 'robotics', 'big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis', 'toward', 'business', 'process', 'innovation', 'big', 'data', 'era', 'mediating', 'role', 'big', 'data', 'knowledge', 'management', 'national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor', 'unstructured', 'big', 'data', 'analytical', 'method', 'firm', 'conceptual', 'model', 'measurement', 'perception', 'big', 'data', 'business', 'bibliometric', 'analysis', 'relevant', 'literature', 'call', 'special', 'issue', 'paper', 'big', 'data', 'business', 'big', 'data', 'social', 'good', 'drought', 'early', 'warning', 'experience', 'report', 'overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization', 'towards', 'quantifying', 'psychiatric', 'diagnosis', 'using', 'machine', 'learning', 'algorithm', 'big', 'fmri', 'data', 'exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink', 'call', 'special', 'issue', 'paper', 'big', 'scientific', 'data', 'machine', 'learning', 'science', 'engineering', 'big', 'data', 'analysis', 'swimming', 'pool', 'impact', 'household', 'electric', 'intensity', 'san', 'antonio', 'texas', 'agricultural', 'disaster', 'risk', 'management', 'capability', 'assessment', 'using', 'big', 'data', 'analytics', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management', 'vehicle', 'intelligent', 'classification', 'based', 'big', 'multimodal', 'data', 'analysis', 'sparrow', 'search', 'optimization', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'big', 'multimodal', 'data', 'analysis', 'application', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'us', 'big', 'data', 'city', 'stgi', 'spatio', 'temporal', 'grid', 'index', 'model', 'marine', 'big', 'data', 'new', 'big', 'data', 'approach', 'based', 'geoecological', 'information', 'modeling', 'system', 'big', 'data', 'literature', 'search', 'big', 'data', 'lost', 'cloud', 'interview', 'dr', 'silvio', 'carta', 'author', 'book', 'big', 'data', 'code', 'discrete', 'city', 'routledge', 'online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data', 'call', 'special', 'issue', 'paper', 'big', 'data', 'business', 'gi', 'based', 'analytical', 'framework', 'evaluating', 'effect', 'covid', 'restaurant', 'industry', 'big', 'data', 'challenge', 'big', 'data', 'earth', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'call', 'special', 'issue', 'paper', 'big', 'data', 'internet', 'thing', 'complex', 'information', 'system', 'selection', 'iotbds', 'complexis', 'data', 'science', 'oceanography', 'small', 'data', 'big', 'data', 'strength', 'number', 'using', 'big', 'data', 'simplify', 'sentiment', 'classification', 'optimizing', 'sentinel', 'image', 'selection', 'big', 'data', 'context', 'atmospheric', 'ecosystem', 'big', 'data', 'providing', 'key', 'contribution', 'reaching', 'united', 'nation', 'sustainable', 'development', 'goal', 'message', 'editor', 'chief', 'big', 'data', 'internet', 'thing', 'based', 'optimized', 'routing', 'big', 'data', 'gathering', 'system', 'landslide', 'detection', 'research', 'dilemma', 'behavioral', 'big', 'data', 'comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink', 'call', 'paper', 'special', 'issue', 'computational', 'propaganda', 'political', 'big', 'data', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', ...

# %%
# 데이터 탐색, 기본 분석 모델 만들기. 
# Counter -> 해당 단어 빈도 집계 해주는 함수. 
count = Counter(words2)
count
# Out:
# Counter({'data': 1227,
#          'big': 1113,
#          'analytics': 126,
#          'based': 121,
#          'analysis': 117,
#          'system': 70,
#          'driven': 67,
#          'approach': 64,
#          'using': 60,
#          'model': 50,
#          'learning': 49,
#          'issue': 48,
#          'application': 44,
#          'management': 41,
#          'new': 40,
#          'framework': 40,
#          'platform': 39,
#          'special': 38,
#          'challenge': 38,
#          'health': 36,
#          'era': 34,
#          'algorithm': 34,
#          'cloud': 34,
#          'call': 33,
#          'science': 32,
#          'paper': 31,
#          'research': 31,
#          'service': 30,
#          'network': 30,
#          'performance': 30,
#          'earth': 29,
#          'method': 28,
#          'processing': 28,
#          'computing': 27,
#          'mining': 27,
#          'machine': 26,
#          'smart': 26,
#          'technology': 24,
#          'real': 24,
#          'perspective': 23,
#          'study': 23,
#          'world': 23,
#          'business': 22,
#          'opportunity': 22,
#          'distributed': 22,
#          'information': 21,
#          'review': 21,
#          'use': 21,
#          'development': 20,
#          'intelligence': 20,
#          'prediction': 20,
#          'efficient': 20,
#          'process': 19,
#          'time': 19,
#          'optimization': 18,
#          'industry': 18,
#          'china': 18,
#          'energy': 18,
#          'future': 18,
#          'der': 18,
#          'survey': 17,
#          'intelligent': 17,
#          'small': 17,
#          'digital': 17,
#          'social': 16,
#          'internet': 16,
#          'deep': 16,
#          'scalable': 16,
#          'editorial': 16,
#          'discovery': 16,
#          'high': 16,
#          'medical': 16,
#          'engineering': 15,
#          'sustainable': 15,
#          'modeling': 15,
#          'environment': 15,
#          'monitoring': 15,
#          'medium': 15,
#          'role': 14,
#          'impact': 14,
#          'classification': 14,
#          'case': 14,
#          'towards': 13,
#          'vehicle': 13,
#          'online': 13,
#          'thing': 13,
#          'human': 13,
#          'care': 13,
#          'multi': 13,
#          'clustering': 13,
#          'guest': 13,
#          'infrastructure': 13,
#          'healthcare': 13,
#          'iot': 13,
#          'making': 13,
#          'evidence': 13,
#          'security': 13,
#          'clinical': 13,
#          'risk': 12,
#          'assessment': 12,
#          'goal': 12,
#          'detection': 12,
#          'solution': 12,
#          'architecture': 12,
#          'distribution': 12,
#          'technique': 12,
#          'r': 12,
#          'practice': 12,
#          'patient': 12,
#          'sharing': 11,
#          'support': 11,
#          'spatial': 11,
#          'pattern': 11,
#          'urban': 11,
#          'understanding': 11,
#          'scale': 11,
#          'large': 11,
#          'state': 11,
#          'decision': 11,
#          'public': 11,
#          'safety': 11,
#          'medicine': 11,
#          'scientific': 10,
#          'city': 10,
#          'building': 10,
#          'quality': 10,
#          'database': 10,
#          'via': 10,
#          'privacy': 10,
#          'control': 10,
#          'problem': 10,
#          'power': 10,
#          'manufacturing': 10,
#          'toward': 9,
#          'visualization': 9,
#          'selection': 9,
#          'education': 9,
#          'green': 9,
#          'little': 9,
#          'transformation': 9,
#          'trend': 9,
#          'value': 9,
#          'semantic': 9,
#          'scheduling': 9,
#          'recommendation': 9,
#          'sensing': 9,
#          'global': 9,
#          'novel': 9,
#          'design': 9,
#          'generation': 9,
#          'improve': 9,
#          'von': 9,
#          'innovation': 8,
#          'knowledge': 8,
#          'disaster': 8,
#          'capability': 8,
#          'search': 8,
#          'covid': 8,
#          'context': 8,
#          'feature': 8,
#          'market': 8,
#          'k': 8,
#          'potential': 8,
#          'storage': 8,
#          'parallel': 8,
#          'memory': 8,
#          'strategy': 8,
#          'chain': 8,
#          'behavior': 8,
#          'enterprise': 8,
#          'insight': 8,
#          'industrial': 8,
#          'warehouse': 8,
#          'device': 8,
#          'question': 8,
#          'policy': 8,
#          'f': 8,
#          'die': 8,
#          'u': 8,
#          'measurement': 7,
#          'intensity': 7,
#          'center': 7,
#          'index': 7,
#          'computational': 7,
#          'de': 7,
#          'sector': 7,
#          'current': 7,
#          'transportation': 7,
#          'sensor': 7,
#          'resource': 7,
#          'estimation': 7,
#          'governance': 7,
#          'financial': 7,
#          'life': 7,
#          'open': 7,
#          'way': 7,
#          'supply': 7,
#          'statistical': 7,
#          'mapreduce': 7,
#          'dynamic': 7,
#          'tool': 7,
#          'evaluation': 7,
#          'advanced': 7,
#          'implication': 7,
#          'access': 7,
#          'critical': 7,
#          'und': 7,
#          'next': 7,
#          'efficiency': 7,
#          'company': 7,
#          'nasopharyngeal': 7,
#          'carcinoma': 7,
#          'radiotherapy': 7,
#          'mean': 7,
#          'national': 6,
#          'mobile': 6,
#          'firm': 6,
#          'literature': 6,
#          'work': 6,
#          'electric': 6,
#          'grid': 6,
#          'evaluating': 6,
#          'complex': 6,
#          'spark': 6,
#          'political': 6,
#          'visual': 6,
#          'web': 6,
#          'fuzzy': 6,
#          'scheme': 6,
#          'adaptive': 6,
#          'aware': 6,
#          'enabled': 6,
#          'e': 6,
#          'meet': 6,
#          'error': 6,
#          'benefit': 6,
#          'project': 6,
#          'implementation': 6,
#          'exploring': 6,
#          'team': 6,
#          'supporting': 6,
#          'oriented': 6,
#          'series': 6,
#          'software': 6,
#          'government': 6,
#          'drug': 6,
#          'promise': 6,
#          'production': 6,
#          'environmental': 6,
#          'revolution': 6,
#          'mit': 6,
#          'moving': 6,
#          'disease': 6,
#          'age': 6,
#          'text': 6,
#          'finding': 6,
#          'scholarship': 6,
#          'bold': 6,
#          'good': 5,
#          'agricultural': 5,
#          'sentiment': 5,
#          'key': 5,
#          'united': 5,
#          'multimedia': 5,
#          'observation': 5,
#          'make': 5,
#          'set': 5,
#          'evolution': 5,
#          'space': 5,
#          'utilization': 5,
#          'query': 5,
#          'assisted': 5,
#          'analyzing': 5,
#          'user': 5,
#          'improved': 5,
#          'leveraging': 5,
#          'overview': 5,
#          'collaboration': 5,
#          'scholarly': 5,
#          'allocation': 5,
#          'air': 5,
#          'heterogeneous': 5,
#          'managing': 5,
#          'operation': 5,
#          'hybrid': 5,
#          'predictive': 5,
#          'theory': 5,
#          'enhanced': 5,
#          'innovative': 5,
#          'kernel': 5,
#          'mobility': 5,
#          'ensemble': 5,
#          'view': 5,
#          'geo': 5,
#          'graph': 5,
#          'mapping': 5,
#          'better': 5,
#          'ai': 5,
#          'compression': 5,
#          'used': 5,
#          'wireless': 5,
#          'communication': 5,
#          'deal': 5,
#          'methodology': 5,
#          'multiple': 5,
#          'predicting': 5,
#          'product': 5,
#          'approximation': 5,
#          'competitive': 5,
#          'car': 5,
#          'im': 5,
#          'labor': 5,
#          'material': 5,
#          'field': 5,
#          'cluster': 5,
#          'artificial': 5,
#          'relationship': 5,
#          'flow': 5,
#          'accurate': 5,
#          'l': 5,
#          'marketing': 5,
#          'help': 5,
#          'offer': 5,
#          'introduction': 5,
#          'dementia': 5,
#          'self': 5,
#          'networked': 5,
#          'futuristic': 5,
#          'fabric': 5,
#          'societal': 5,
#          'conceptual': 4,
#          'bibliometric': 4,
#          'early': 4,
#          'warning': 4,
#          'experience': 4,
#          'report': 4,
#          'operational': 4,
#          'change': 4,
#          'diagnosis': 4,
#          'exploiting': 4,
#          'multimodal': 4,
#          'international': 4,
#          'temporal': 4,
#          'interview': 4,
#          'effect': 4,
#          'cybersecurity': 4,
#          'image': 4,
#          'gathering': 4,
#          'behavioral': 4,
#          'apache': 4,
#          'level': 4,
#          'sport': 4,
#          'nearest': 4,
#          'region': 4,
#          'consumption': 4,
#          'stock': 4,
#          'recent': 4,
#          'nosql': 4,
#          'stream': 4,
#          'similarity': 4,
#          'secure': 4,
#          'simulation': 4,
#          'flexible': 4,
#          'task': 4,
#          'commerce': 4,
#          'content': 4,
#          'handling': 4,
#          'anomaly': 4,
#          'reference': 4,
#          'matrix': 4,
#          'identification': 4,
#          'frontier': 4,
#          'comprehensive': 4,
#          'remote': 4,
#          'processor': 4,
#          'semantics': 4,
#          'map': 4,
#          'sampling': 4,
#          'bayesian': 4,
#          'phase': 4,
#          'hadoop': 4,
#          'transforming': 4,
#          'integration': 4,
#          'paradigm': 4,
#          'forecasting': 4,
#          'fusion': 4,
#          'investigation': 4,
#          'applying': 4,
#          'cell': 4,
#          'tensor': 4,
#          'incremental': 4,
#          'uncertainty': 4,
#          'dimension': 4,
#          'correction': 4,
#          'v': 4,
#          'non': 4,
#          'correlation': 4,
#          'advantage': 4,
#          'law': 4,
#          'student': 4,
#          'individual': 4,
#          'lesson': 4,
#          'advance': 4,
#          'informatics': 4,
#          'concept': 4,
#          'emergence': 4,
#          'tracking': 4,
#          'politics': 4,
#          'analysen': 4,
#          'child': 4,
#          'price': 4,
#          'traditional': 4,
#          'precision': 4,
#          'area': 4,
#          'cancer': 4,
#          'biology': 4,
#          'deadline': 4,
#          'cost': 4,
#          'p': 4,
#          'top': 4,
#          'modulated': 4,
#          'hospital': 4,
#          'association': 4,
#          'training': 4,
#          'provides': 4,
#          'pp': 4,
#          'isbn': 4,
#          'cognitive': 4,
#          'robotics': 3,
#          'population': 3,
#          'unstructured': 3,
#          'analytical': 3,
#          'perception': 3,
#          'interactive': 3,
#          'continued': 3,
#          'code': 3,
#          'gi': 3,
#          'optimizing': 3,
#          'contribution': 3,
#          'message': 3,
#          'editor': 3,
#          'propaganda': 3,
#          'telecom': 3,
#          'neural': 3,
#          'sparse': 3,
#          'geospatial': 3,
#          'stakeholder': 3,
#          'response': 3,
#          'neighbor': 3,
#          'status': 3,
#          'optimal': 3,
#          'interval': 3,
#          'modelling': 3,
#          'scholar': 3,
#          'landscape': 3,
#          'finance': 3,
#          'patent': 3,
#          'demand': 3,
#          'deduplication': 3,
#          'evolving': 3,
#          'extended': 3,
#          'corporate': 3,
#          'functional': 3,
#          'pipeline': 3,
#          'fast': 3,
#          'extraction': 3,
#          'concern': 3,
#          'independent': 3,
#          'preserving': 3,
#          'barrier': 3,
#          'smes': 3,
#          'structural': 3,
#          'rating': 3,
#          'five': 3,
#          'classifier': 3,
#          'factorization': 3,
#          'traffic': 3,
#          'interoperability': 3,
#          'compute': 3,
#          'alternative': 3,
#          'core': 3,
#          'generalized': 3,
#          'engine': 3,
#          'emerging': 3,
#          'blood': 3,
#          'improving': 3,
#          'reduce': 3,
#          'bigger': 3,
#          'biggest': 3,
#          'practical': 3,
#          'regression': 3,
#          'leverage': 3,
#          'initiative': 3,
#          'reducing': 3,
#          'collection': 3,
#          'dimensional': 3,
#          'programming': 3,
#          'physical': 3,
#          'academic': 3,
#          'library': 3,
#          'dream': 3,
#          'reduction': 3,
#          'determinant': 3,
#          'scenario': 3,
#          'rule': 3,
#          'regional': 3,
#          'twitter': 3,
#          'factory': 3,
#          'relation': 3,
#          'natural': 3,
#          'mechanism': 3,
#          'theoretical': 3,
#          'group': 3,
#          'store': 3,
#          'genome': 3,
#          'community': 3,
#          'aggregation': 3,
#          'recovery': 3,
#          'hot': 3,
#          'factor': 3,
#          'course': 3,
#          'candidate': 3,
#          'screening': 3,
#          'edge': 3,
#          'throughput': 3,
#          'discussion': 3,
#          'carbon': 3,
#          'prospect': 3,
#          'spectrum': 3,
#          'growth': 3,
#          'x': 3,
#          'imaging': 3,
#          'zur': 3,
#          'type': 3,
#          'gene': 3,
#          'three': 3,
#          'workflow': 3,
#          'comparative': 3,
#          'c': 3,
#          'tourism': 3,
#          'informed': 3,
#          'sleep': 3,
#          'becoming': 3,
#          'dissemination': 3,
#          'ecology': 3,
#          'activity': 3,
#          'pandemic': 3,
#          'pain': 3,
#          'researcher': 3,
#          'ethic': 3,
#          'logistics': 3,
#          'ground': 3,
#          'genomics': 3,
#          'bike': 3,
#          'expanding': 3,
#          'al': 3,
#          'analyse': 3,
#          'workload': 3,
#          'medizin': 3,
#          'gpu': 3,
#          'reward': 3,
#          'need': 3,
#          'pmu': 3,
#          'organizational': 3,
#          'nonvolatile': 3,
#          'domain': 3,
#          'putting': 3,
#          'stochastic': 3,
#          'zum': 3,
#          'randomized': 3,
#          'think': 3,
#          'general': 3,
#          'cross': 3,
#          'interconnection': 3,
#          'exascale': 3,
#          'among': 3,
#          'comment': 3,
#          'improvement': 3,
#          'audit': 3,
#          'genetic': 3,
#          'therapy': 3,
#          'fault': 3,
#          'anti': 3,
#          'wide': 3,
#          'anatomy': 3,
#          'action': 3,
#          'asia': 3,
#          'start': 3,
#          'filter': 3,
#          'chinese': 3,
#          'donepezil': 3,
#          'comorbidity': 3,
#          'alzheimer': 3,
#          'japan': 3,
#          'made': 3,
#          'marketer': 3,
#          'water': 3,
#          'gain': 3,
#          'lawyer': 3,
#          'internal': 3,
#          'christine': 3,
#          'borgman': 3,
#          'press': 3,
#          'optimize': 3,
#          'brother': 3,
#          'school': 3,
#          'personalized': 3,
#          'trauma': 3,
#          'biomedical': 3,
#          'restaurant': 2,
#          'relevant': 2,
#          'resistance': 2,
#          'quantifying': 2,
#          'fmri': 2,
#          'flink': 2,
#          'celebration': 2,
#          'establishment': 2,
#          'cbas': 2,
#          'spatio': 2,
#          'lost': 2,
#          'author': 2,
#          'strength': 2,
#          'sentinel': 2,
#          'ecosystem': 2,
#          'optimized': 2,
#          'routing': 2,
#          'comparison': 2,
#          'batch': 2,
#          'assurance': 2,
#          'combining': 2,
#          'aerial': 2,
#          'differential': 2,
#          'binary': 2,
#          'tree': 2,
#          'ocean': 2,
#          'coverage': 2,
#          'insurance': 2,
#          'centric': 2,
#          'datasets': 2,
#          'partitioning': 2,
#          'taxi': 2,
#          'availability': 2,
#          'consistency': 2,
#          'eeg': 2,
#          'shared': 2,
#          'causality': 2,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'fraud': 2,
#          'news': 2,
#          'ethical': 2,
#          'uk': 2,
#          'strategic': 2,
#          'reconstruction': 2,
#          'scaling': 2,
#          'surveillance': 2,
#          'economic': 2,
#          'metadata': 2,
#          'extracting': 2,
#          'searching': 2,
#          'thermal': 2,
#          'qualitative': 2,
#          'overcome': 2,
#          'trajectory': 2,
#          'provision': 2,
#          'semantically': 2,
#          'layer': 2,
#          'svm': 2,
#          'vector': 2,
#          'banking': 2,
#          'lightweight': 2,
#          'random': 2,
#          'forest': 2,
#          'situation': 2,
#          'awareness': 2,
#          'approximate': 2,
#          'structured': 2,
#          'co': 2,
#          'labeling': 2,
#          'ontology': 2,
#          'landsat': 2,
#          'supervised': 2,
#          'google': 2,
#          'first': 2,
#          'climate': 2,
#          'belt': 2,
#          'road': 2,
#          'australian': 2,
#          'ship': 2,
#          'donation': 2,
#          'repository': 2,
#          'coping': 2,
#          'moderating': 2,
#          'culture': 2,
#          'formal': 2,
#          'divide': 2,
#          'maturity': 2,
#          'yield': 2,
#          'designing': 2,
#          'mine': 2,
#          'build': 2,
#          'em': 2,
#          'condition': 2,
#          'theme': 2,
#          'electrophysiology': 2,
#          'complexity': 2,
#          'swarm': 2,
#          'belief': 2,
#          'conference': 2,
#          'peer': 2,
#          'pharmaceutical': 2,
#          'securing': 2,
#          'experimental': 2,
#          'proactive': 2,
#          'criminal': 2,
#          'portfolio': 2,
#          'librarian': 2,
#          'skill': 2,
#          'grand': 2,
#          'michael': 2,
#          'buck': 2,
#          'catalyst': 2,
#          'enabling': 2,
#          'computation': 2,
#          'convergent': 2,
#          'mr': 2,
#          'matching': 2,
#          'economy': 2,
#          'construction': 2,
#          'comparing': 2,
#          'advancing': 2,
#          'success': 2,
#          'join': 2,
#          'direction': 2,
#          'decomposition': 2,
#          'virtual': 2,
#          'sequence': 2,
#          'sample': 2,
#          'simple': 2,
#          'pre': 2,
#          'sequential': 2,
#          'localization': 2,
#          'effective': 2,
#          'dataset': 2,
#          'imputation': 2,
#          'free': 2,
#          'gaussian': 2,
#          'order': 2,
#          'face': 2,
#          'site': 2,
#          'b': 2,
#          'old': 2,
#          'simplified': 2,
#          'zukunft': 2,
#          'anwendungen': 2,
#          'chancen': 2,
#          'herausforderungen': 2,
#          'mo': 2,
#          'working': 2,
#          'interaction': 2,
#          'oracle': 2,
#          'sparc': 2,
#          'also': 2,
#          'ready': 2,
#          'battery': 2,
#          'beijing': 2,
#          'transfer': 2,
#          'protein': 2,
#          'structure': 2,
#          'boost': 2,
#          'fur': 2,
#          'empirical': 2,
#          'credit': 2,
#          'econophysics': 2,
#          'technical': 2,
#          'prevention': 2,
#          'satellite': 2,
#          'variation': 2,
#          'stem': 2,
#          'smallholder': 2,
#          'oil': 2,
#          'program': 2,
#          'streaming': 2,
#          'au': 2,
#          'influencing': 2,
#          'expression': 2,
#          'film': 2,
#          'track': 2,
#          'stack': 2,
#          'capital': 2,
#          'bioinformatics': 2,
#          'technologien': 2,
#          'drive': 2,
#          'meter': 2,
#          'rhetoric': 2,
#          'worker': 2,
#          'neuroimaging': 2,
#          'disorder': 2,
#          'encryption': 2,
#          'cryptography': 2,
#          'reinforcement': 2,
#          'blending': 2,
#          'healthy': 2,
#          'laboratory': 2,
#          'consideration': 2,
#          'job': 2,
#          'employee': 2,
#          'savvy': 2,
#          'south': 2,
#          'korea': 2,
#          'increased': 2,
#          'animal': 2,
#          'target': 2,
#          'capturing': 2,
#          'say': 2,
#          'surface': 2,
#          'fitting': 2,
#          'aircraft': 2,
#          'targeted': 2,
#          'available': 2,
#          'doi': 2,
#          'st': 2,
#          'still': 2,
#          'possible': 2,
#          'dual': 2,
#          'edited': 2,
#          'unmanned': 2,
#          'art': 2,
#          'spur': 2,
#          'ist': 2,
#          'waste': 2,
#          'jbhi': 2,
#          'zu': 2,
#          'einfluss': 2,
#          'auf': 2,
#          'announcement': 2,
#          'missing': 2,
#          'diabetes': 2,
#          'noch': 2,
#          'verlaufen': 2,
#          'projekte': 2,
#          'ganz': 2,
#          'anders': 2,
#          'geplant': 2,
#          'career': 2,
#          'graduate': 2,
#          'charging': 2,
#          'studie': 2,
#          'york': 2,
#          'exploration': 2,
#          'enhancing': 2,
#          'cover': 2,
#          'pressure': 2,
#          'seeking': 2,
#          'dividend': 2,
#          'joining': 2,
#          'eva': 2,
#          'style': 2,
#          'thema': 2,
#          'pr': 2,
#          'agenda': 2,
#          'ownership': 2,
#          'fine': 2,
#          'mode': 2,
#          'jd': 2,
#          'com': 2,
#          'emergency': 2,
#          'planning': 2,
#          'convergence': 2,
#          'must': 2,
#          'starting': 2,
#          'stage': 2,
#          'pitfall': 2,
#          'phylogenetics': 2,
#          'land': 2,
#          'hat': 2,
#          'position': 2,
#          'ad': 2,
#          'cycle': 2,
#          'identifying': 2,
#          'purpose': 2,
#          'expert': 2,
#          'den': 2,
#          'elastic': 2,
#          'tech': 2,
#          'dem': 2,
#          'adult': 2,
#          'trial': 2,
#          'sequencing': 2,
#          'get': 2,
#          'focus': 2,
#          'proxy': 2,
#          'inference': 2,
#          'statistic': 2,
#          'determine': 2,
#          'common': 2,
#          'epidemiology': 2,
#          'primary': 2,
#          'long': 2,
#          'endemic': 2,
#          'treated': 2,
#          'creation': 2,
#          'mortality': 2,
#          'admission': 2,
#          'versus': 2,
#          'event': 2,
#          'article': 2,
#          'gated': 2,
#          'recurrent': 2,
#          'unit': 2,
#          'brain': 2,
#          'army': 2,
#          'trade': 2,
#          'forward': 2,
#          'remaining': 2,
#          'gearbox': 2,
#          'mental': 2,
#          'leadership': 2,
#          'hacker': 2,
#          'behave': 2,
#          'distance': 2,
#          'discrimination': 2,
#          'convex': 2,
#          'potenziale': 2,
#          'ldquor': 2,
#          'singapore': 2,
#          'mhc': 2,
#          'crunch': 2,
#          'utilizing': 2,
#          'travel': 2,
#          'kind': 2,
#          'wcn': 2,
#          'crowdfunding': 2,
#          'locoregionally': 2,
#          'tcam': 2,
#          'reram': 2,
#          'frequent': 2,
#          'instant': 2,
#          'utility': 2,
#          'size': 2,
#          'demographic': 2,
#          'survival': 2,
#          'outcome': 2,
#          'psychological': 2,
#          'beginning': 2,
#          'low': 2,
#          'noise': 2,
#          'filtering': 2,
#          'biological': 2,
#          'topic': 2,
#          'total': 2,
#          'interdisciplinary': 2,
#          'continuous': 2,
#          'society': 2,
#          'addressing': 2,
#          'one': 2,
#          'federal': 2,
#          'aim': 2,
#          'amp': 2,
#          'require': 2,
#          'scientist': 2,
#          'pay': 2,
#          'swd': 2,
#          'unlock': 2,
#          'customer': 2,
#          'reprocessing': 2,
#          'fda': 2,
#          'headache': 2,
#          'personal': 2,
#          'look': 2,
#          'hardcover': 2,
#          'measured': 2,
#          'demystifying': 2,
#          'developmental': 2,
#          'really': 2,
#          'create': 2,
#          'hype': 2,
#          'analyze': 2,
#          'matter': 2,
#          'transform': 2,
#          'rt': 2,
#          'variability': 2,
#          'identified': 2,
#          'lambda': 2,
#          'consortium': 2,
#          'oncology': 2,
#          'reimbursement': 2,
#          'philosophy': 2,
#          'part': 2,
#          'aadhaar': 2,
#          'attack': 2,
#          'difference': 2,
#          'envelopment': 2,
#          'rescue': 2,
#          'geoinformatics': 2,
#          'karimi': 2,
#          'crc': 2,
#          'mary': 2,
#          'consequence': 2,
#          ...})

# %%
# 임시 딕션너리 만들기. 
word_count = dict()

# 상위 50개 정도만 추출 해보기. 
for tag, counts in count.most_common(50):
  if(len(str(tag)) >1):
    word_count[tag] = counts
    # print(f"tag : {tag}, counts : {counts}")

word_count
# Out:
# tag : data, counts : 1227
# tag : big, counts : 1113
# tag : analytics, counts : 126
# tag : based, counts : 121
# tag : analysis, counts : 117
# tag : system, counts : 70
# tag : driven, counts : 67
# tag : approach, counts : 64
# tag : using, counts : 60
# tag : model, counts : 50
# tag : learning, counts : 49
# tag : issue, counts : 48
# tag : application, counts : 44
# tag : management, counts : 41
# tag : new, counts : 40
# tag : framework, counts : 40
# tag : platform, counts : 39
# tag : special, counts : 38
# tag : challenge, counts : 38
# tag : health, counts : 36
# tag : era, counts : 34
# tag : algorithm, counts : 34
# tag : cloud, counts : 34
# tag : call, counts : 33
# tag : science, counts : 32
# tag : paper, counts : 31
# tag : research, counts : 31
# tag : service, counts : 30
# tag : network, counts : 30
# tag : performance, counts : 30
# tag : earth, counts : 29
# tag : method, counts : 28
# tag : processing, counts : 28
# tag : computing, counts : 27
# tag : mining, counts : 27
# tag : machine, counts : 26
# tag : smart, counts : 26
# tag : technology, counts : 24
# tag : real, counts : 24
# tag : perspective, counts : 23
# tag : study, counts : 23
# tag : world, counts : 23
# tag : business, counts : 22
# tag : opportunity, counts : 22
# tag : distributed, counts : 22
# tag : information, counts : 21
# tag : review, counts : 21
# tag : use, counts : 21
# tag : development, counts : 20
# tag : intelligence, counts : 20
# {'data': 1227,
#  'big': 1113,
#  'analytics': 126,
#  'based': 121,
#  'analysis': 117,
#  'system': 70,
#  'driven': 67,
#  'approach': 64,
#  'using': 60,
#  'model': 50,
#  'learning': 49,
#  'issue': 48,
#  'application': 44,
#  'management': 41,
#  'new': 40,
#  'framework': 40,
#  'platform': 39,
#  'special': 38,
#  'challenge': 38,
#  'health': 36,
#  'era': 34,
#  'algorithm': 34,
#  'cloud': 34,
#  'call': 33,
#  'science': 32,
#  'paper': 31,
#  'research': 31,
#  'service': 30,
#  'network': 30,
#  'performance': 30,
#  'earth': 29,
#  'method': 28,
#  'processing': 28,
#  'computing': 27,
#  'mining': 27,
#  'machine': 26,
#  'smart': 26,
#  'technology': 24,
#  'real': 24,
#  'perspective': 23,
#  'study': 23,
#  'world': 23,
#  'business': 22,
#  'opportunity': 22,
#  'distributed': 22,
#  'information': 21,
#  'review': 21,
#  'use': 21,
#  'development': 20,
#  'intelligence': 20}

# %%
# 추출된 상위 50개 단어 시각화하기. 
# 막대그래프 
# word_count : 상위 50개 단어 추출한 , 딕션너리 = Map 비슷 ,key : value 
# 기본이 : 오름 차순, reverse, 내림 차순이라고 보면 됨. 
sorted_Keys = sorted(word_count, key = word_count.get, reverse=True)

# values 추출, 내림 차순 
sorted_Values= sorted(word_count.values(), reverse=True)

# 시각화 
# x축 : range(len(word_count))
# Y축 : sorted_Values
plt.bar(range(len(word_count)),sorted_Values, align='center')
# 눈금 옵션 조정. x축 라벨 붙이기 작업. rotation 세로 방향으로 기울이기. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# 기존 데이터 프레임에 새로운 컬럼(doc_count) 추가, 임의로 0으로 값 넣기. 
all_files_data_concat["doc_count"] = 0

#  출판일 기준으로 그룹화해서, count 집계 표기 하기. 
summary_date = all_files_data_concat.groupby("출판일", as_index=False)["doc_count"].count()
summary_date
# Out:
#      출판일  doc_count
# 0   1999          1
# 1   2004          1
# 2   2011          4
# 3   2012         14
# 4   2013         38
# 5   2014         92
# 6   2015         78
# 7   2016        101
# 8   2017        113
# 9   2018        112
# 10  2019         75
# 11  2020         87
# 12  2021         78
# 13  2022         72
# 14  2023         34
# 15     -          2
# 16  2012          1
# 17  2013          2
# 18  2014          3
# 19  2015          6
# 20  2016         14
# 21  2017         12
# 22  2018         10
# 23  2019         10
# 24  2020         15
# 25  2021         16
# 26  2022          4
# 27  2023          5

# %%
# 꺽은선 그래프 
# 가로 세로 비율
plt.figure(figsize=(20,5))
plt.xlabel("year")
plt.ylabel("doc_count")
plt.grid(True)
# x축 : range(len(summary_date))
# y축 : summary_date["doc_count"]
plt.plot(range(len(summary_date)), summary_date["doc_count"] )
# x축 라벨링 옵션 
plt.xticks(range(len(summary_date)), [text for text in summary_date["출판일"]])
plt.show()

# %%
# 워드 클라우드 공식 문서 , 다양한 이미지 위에 처리하기. 
# https://amueller.github.io/word_cloud/index.html

# 워드 클라우드 시각화 
stopwords = set(STOPWORDS)
wc = WordCloud(background_color="ivory", stopwords=stopwords, width=800, height=600)
cloud = wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis("off")
plt.show()
# data': 1235,
#  'big': 1113,
#  'analytics': 110,
#  'based': 102,
#  'analysis': 93,
#  'driven': 70,
#  'system': 64,
#  'using': 57,
